# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Salary Data.csv',usecols = ['Years of Experience','Salary'])
dataset = dataset.dropna()
dataset
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 2 columns]

# %%
dataset['Years of Experience'] #YO garda numpy array ma hunna yeslai numpy ma lana parxa hamile always
# Out:
# 0       5.0
# 1       3.0
# 2      15.0
# 3       7.0
# 4      20.0
#        ...
# 370     8.0
# 371    19.0
# 372     2.0
# 373     7.0
# 374    15.0
# Name: Years of Experience, Length: 373, dtype: float64

# %%
#converting into numpy array  
#hamilai table ko years of experience matra chaiyeko xa tesko coz YOE is independent variable where it is kept in 'X'
X = dataset.iloc[:, 0:-1].values #dataset.iloc[:,0:-1] le chai last column jun ma salary xa tyo lidaina ie takes only the value of YOE and aagadi ko : le chai savai row lyi vaneko

X


# #yo or yeslai yesari ni garna milxa
# X=dataset[['Years of Experience']].values
# X
# Out:
# array([[ 5. ],
#        [ 3. ],
#        [15. ],
#        [ 7. ],
#        [20. ],
#        [ 2. ],
#        [12. ],
#        [ 4. ],
#        [ 1. ],
#        [10. ],
#        [ 3. ],
#        [18. ],
#        [ 6. ],
#        [14. ],
#        [ 2. ],
#        [16. ],
#        [ 7. ],
#        [12. ],
#        [ 0. ],
#        [22. ],
#        [ 5. ],
#        [19. ],
#        [ 2. ],
#        [ 9. ],
#        [13. ],
#        [ 3. ],
#        [11. ],
#        [ 1. ],
#        [15. ],
#        [ 6. ],
#        [25. ],
#        [ 4. ],
#        [ 3. ],
#        [10. ],
#        [20. ],
#        [ 2. ],
#        [ 7. ],
#        [14. ],
#        [ 1. ],
#        [21. ],
#        [ 5. ],
#        [18. ],
#        [ 3. ],
#        [ 8. ],
#        [13. ],
#        [ 2. ],
#        [ 5. ],
#        [16. ],
#        [11. ],
#        [ 0. ],
#        [22. ],
#        [ 7. ],
#        [12. ],
#        [19. ],
#        [ 3. ],
#        [ 9. ],
#        [ 2. ],
#        [17. ],
# ...

# %%
#Similarly hamile y ko value rakhna parxa y chai salary ho so extracting values of all rows of the last column
Y = dataset.iloc[:,1:].values
Y
# Out:
# array([[ 90000.],
#        [ 65000.],
#        [150000.],
#        [ 60000.],
#        [200000.],
#        [ 55000.],
#        [120000.],
#        [ 80000.],
#        [ 45000.],
#        [110000.],
#        [ 75000.],
#        [140000.],
#        [ 65000.],
#        [130000.],
#        [ 40000.],
#        [125000.],
#        [ 90000.],
#        [115000.],
#        [ 35000.],
#        [180000.],
#        [ 80000.],
#        [190000.],
#        [ 50000.],
#        [ 60000.],
#        [140000.],
#        [ 45000.],
#        [110000.],
#        [ 40000.],
#        [140000.],
#        [ 90000.],
#        [250000.],
#        [ 55000.],
#        [ 75000.],
#        [ 65000.],
#        [170000.],
#        [ 45000.],
#        [ 60000.],
#        [115000.],
#        [ 40000.],
#        [160000.],
#        [ 80000.],
#        [190000.],
#        [ 60000.],
#        [ 45000.],
#        [130000.],
#        [ 40000.],
#        [ 75000.],
#        [180000.],
#        [120000.],
#        [ 35000.],
# ...

# %%
# #mathi ko iloc wala ko satta yo ni garna milxa
# Y=dataset[['Salary']].values
# Y

# %%
#splitting datasets into train and test datasets
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.1,random_state = 10) #test_size=0.1 vaneko 10 percent data testing lai xutyako ani random_state=10 vaneko chai data lai shuffle gareko (data mining ko random sub sampling gareko)

# %%
#just to know the total length not necessary to do
total_len=(len(X))
print('All total length =',total_len)
print('X_Train length =',len(X_train))
print('X_Test length =',len(X_test))
# Out:
# All total length = 373
# X_Train length = 335
# X_Test length = 38

# %%
#Training model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
#now the <<model>> object is prediction object
# Out:
# LinearRegression()

# %%
#testing model
exp = float(input("Enter years of experience = "))
exp = np.array([[exp]]) #hamile savai operations garne numpy array ma ho so tesma convert gareko. This is because yo case ma hamile model lai numpy ma train gareko xam 
# print(exp)

# # predict the salary
predicted_salary = model.predict(exp) #yo matra garda salary numpy ma auxa ie. [["SALARY"]] ko form ma 
predicted_salary = model.predict(exp)[0][0] #[["SALARY"]] bata "SALARY" jhikeko as salary lies in 0th index 0th element
# print(predicted_salary)
print("Your predicted_salary = ",predicted_salary)
# Out:
# Enter years of experience = 0
# Your predicted_salary =  32131.93187154649

# %%
# predicted_salary = model.predict(X_test)
# for i in range(len(X_test)):
#     print(X_test[i][0],Y_test[i][0],predicted_salary[i][0])

# %%
# for testing data
predicted_salary = model.predict(X_test)
# print(predicted_salary)
for i in range(len(X_test)):
    print("Years of experiance",X_test.tolist()[i][0], "     salary",predicted_salary[i][0], "     Actual Salary",Y_test.tolist()[i][0])  #Y_test le chai actual salary deko xa yo chai accuracy nikalna

# actualtotal=np.sum(Y_test)
# obtainedtotal=np.sum(predicted_salary)

# accuracy=(1-abs((obtainedtotal-actualtotal)/actualtotal))*100
# print("The accuracy of the model is ",accuracy,'%')
# Out:
# Years of experiance 16.0      salary 141326.43605535757      Actual Salary 140000.0
# Years of experiance 17.0      salary 148151.09256684576      Actual Salary 160000.0
# Years of experiance 22.0      salary 182274.37512428671      Actual Salary 180000.0
# Years of experiance 20.0      salary 168625.06210131035      Actual Salary 180000.0
# Years of experiance 21.0      salary 175449.71861279852      Actual Salary 190000.0
# Years of experiance 7.0      salary 79904.52745196383      Actual Salary 95000.0
# Years of experiance 14.0      salary 127677.12303238118      Actual Salary 110000.0
# Years of experiance 1.5      salary 42368.91663877878      Actual Salary 40000.0
# Years of experiance 22.0      salary 182274.37512428671      Actual Salary 160000.0
# Years of experiance 20.0      salary 168625.06210131035      Actual Salary 180000.0
# Years of experiance 10.0      salary 100378.49698642842      Actual Salary 120000.0
# ...

# %%
#to plot the regression line graph
#to plot points
plt.scatter(X_train,Y_train,color = 'red')
#yesle regression line lai banauxa as train gareko data lai model ma halera tesle deko output le regression line banauxa
plt.plot(X_train,model.predict(X_train),color = 'blue') 
plt.show()

# %%
#for test dataset checking if the regression line from training is valid or not

#plotting the points for test datas
plt.scatter(X_test,Y_test,color = 'red')

# plotting the line of the same training datas (Mathi kei blue line plot gareko so X_train haru xa)
plt.plot(X_train,model.predict(X_train),color = 'blue')
plt.show()

# %%
#to compare predicted values for test set vs the actual values for test set 

plt.scatter(Y_test,model.predict(X_test),color = 'red')
plt.xlabel('Actual value')
plt.ylabel('Predicted value')
plt.title('actual value vs predicted value for test datas')
plt.show()
